# %% [markdown]
# # Python PIP - Python Package Manager(Python Paket Yöneticisi)
#
# PIP, tercih edilen yükleyici programı anlamına gelir. Farklı Python paketleri kurmak için pip kullanıyoruz. Paket yönetim sistemi geliştiriciler tarafından hazırlanan o dile ya da yazılıma ait kütüphaneleri tek komut kullanarak kolayca yükleyebilmenizi, güncelleyebilmenizi ve isterseniz silebilmenizi sağlayan araçtır. Paket, bir veya daha fazla modül veya başka paketler içerebilen bir Python modülüdür. Uygulamamıza yükleyebileceğimiz modül veya modüller bir pakettir. Programlamada her yardımcı programı yazmak zorunda değiliz, bunun yerine paketleri kurup uygulamalarımıza aktarıyoruz.
#
# ### Installing PIP(PIP Yükleme)
#
# PIP yüklemesini teminale veya komut sistemine aşağıdaki ifadeyi yazarak kurulumunu gerçekleştirebiliriz.
#
# * pip install pip
#
# Farklı uygulamalarda kullanabileceğiniz çok sayıda paket vardır.
#
# ### Installing packages using pip(pip kullarak paket yüklemek)
#
# Sayısal veriler üzerine çalıltığımız ve en çok kullanılan NumPy ve Pandas kütüphanelerini inceleyelim.
#
# •	Numpy ,Python ile bilimsel hesaplama için temel pakettir. Diğer şeylerin yanı sıra şunları içerir:
#
# Güçlü bir N boyutlu dizi nesnesi
#
# Gelişmiş (yayın) işlevleri
#
# C/C++ ve Fortran kodunu entegre etmek için araçlar
#
# Faydalı lineer cebir, Fourier dönüşümü ve rasgele sayı yetenekleri
#
# Numpy kütüphanesini şimdi pip ile kurulumunu yapalım.
#
# PS C:\Users\Büşra> pip install numpy
#
# •	Pandas, Python programlama dili için yüksek performanslı, kullanımı kolay veri yapıları ve veri analiz araçları sağlayan açık kaynaklı, BSD lisanslı bir kitaplıktır. Numpy'nin ağabeyi pandaları yükleyelim.
#
#
#
# ### Uninstalling Packages(Paket Kaldırma)
#
# Kurulu paketleri saklamak istemiyorsanız, aşağıdaki komutu kullanarak bunları kaldırabilirsiniz.

# %% [markdown]
# pip uninstall packagename

# %% [markdown]
# ### Paket Listesi
#
# Makinemizde kurulu paketleri görmek için. Pip ve ardından liste kullanabiliriz.

# %% [markdown]
# pip list

# %%
Package                           Version
--------------------------------- ---------
anyio                             3.1.0
argon2-cffi                       20.1.0
async-generator                   1.10
attrs                             21.2.0
Babel                             2.9.1
backcall                          0.2.0
backports.entry-points-selectable 1.1.1
beautifulsoup4                    4.10.0
bleach                            3.3.0
bs4                               0.0.1
certifi                           2021.5.30
cffi                              1.14.5
chardet                           4.0.0
colorama                          0.4.4
cycler                            0.10.0
DateTime                          4.3
debugpy                           1.5.1
decorator                         5.0.9
defusedxml                        0.7.1
distlib                           0.3.4
entrypoints                       0.3
et-xmlfile                        1.1.0
filelock                          3.4.0
fit                               0.4.1
idna                              2.10
ipykernel                         6.5.1
ipython                           7.24.1
ipython-genutils                  0.2.0
jedi                              0.18.0
Jinja2                            3.0.1
joblib                            1.0.1
json5                             0.9.5
jsonschema                        3.2.0
jupyter-client                    6.1.12
jupyter-core                      4.7.1
jupyter-server                    1.8.0
jupyterlab                        3.0.16
jupyterlab-pygments               0.1.2
jupyterlab-server                 2.6.0
kiwisolver                        1.3.1
lxml                              4.6.4
MarkupSafe                        2.0.1
matplotlib                        3.4.2
matplotlib-inline                 0.1.2
matplotlip                        0.2
mistune                           0.8.4
myModule                          1.0.0
nbclassic                         0.3.1
nbclient                          0.5.3
nbconvert                         6.0.7
nbformat                          5.1.3
nest-asyncio                      1.5.1
notebook                          6.4.0
numpy                             1.20.3
openpyxl                          3.0.9
packaging                         20.9
pandas                            1.2.4
pandocfilters                     1.4.3
parso                             0.8.2
patsy                             0.5.1
pickleshare                       0.7.5
Pillow                            8.2.0
pip                               21.1.2
platformdirs                      2.4.0
prometheus-client                 0.11.0
prompt-toolkit                    3.0.18
pycparser                         2.20
Pygments                          2.9.0
pyparsing                         2.4.7
pyrsistent                        0.17.3
python-dateutil                   2.8.1
pytz                              2021.1
pywin32                           301
pywinpty                          1.1.2
pyzmq                             22.1.0
read                              0.0.2
requests                          2.25.1
scikit-learn                      0.24.2
scipy                             1.6.3
seaborn                           0.11.1
Send2Trash                        1.5.0
setuptools                        56.0.0
six                               1.16.0
sklearn                           0.0
sniffio                           1.2.0
soupsieve                         2.3.1
statsmodels                       0.12.2
terminado                         0.10.1
testpath                          0.5.0
threadpoolctl                     2.1.0
tornado                           6.1
traitlets                         5.1.1
urllib3                           1.26.5
virtualenv                        20.10.0
wcwidth                           0.2.5
webencodings                      0.5.1
websocket-client                  1.1.0
wheel                             0.36.2
workbook                          1.1
xlrd                              2.0.1
XlsxWriter                        3.0.2
xlutils                           2.0.0
xlwt                              1.3.0
zope.interface                    5.4.0
WARNING: You are using pip version 21.1.2; however, version 21.3.1 is available.
You should consider upgrading via the 'c:\users\büşra\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# ### Paketi Göster
#
# Bir paketle ilgili bilgileri göstermek için

# %% [markdown]
# pip show packagename

# %%
pip show pandas
Name: pandas
Version: 1.2.4
Summary: Powerful data structures for data analysis, time series, and statistics
Home-page: https://pandas.pydata.org
Author: None
Author-email: None
License: BSD
Location: c:\users\büşra\appdata\local\programs\python\python39\lib\site-packages
Requires: numpy, pytz, python-dateutil
Required-by: statsmodels, seaborn

# %% [markdown]
# ### PIP Dondurma
#
# Sürümleriyle birlikte kurulu Python paketleri oluşturun ve çıktı, onu bir gereksinim dosyasında kullanmaya uygundur. Gereksinimler.txt dosyası, bir Python projesinde kurulu tüm Python paketlerini içermesi gereken bir dosyadır.

# %% [markdown]
# ### URL'den okuma
#
# Artık yerel bilgisayarımızda  bulunan bir dosyayı nasıl okuyacağınızı veya yazacağınızı biliyorsunuz. Bazen bir web sitesinden url veya bir API kullanarak okumak isteriz. API, Uygulama Programı Arayüzü anlamına gelir. Yapılandırılmış verileri sunucular arasında öncelikle json verileri olarak değiş tokuş etmenin bir yoludur. Bir ağ bağlantısı açmak için, denilen bir pakete ihtiyaç istekleri - bir ağ bağlantısı açmak ve CRUD (crud) işlemleri uygulamak için izin verir.Haydi bakalım.

# %% [markdown]
# * İstekler modülünde get , status_code , headers , text ve json yöntemlerini göreceğiz :
#
# get() : bir ağ açmak ve url'den veri almak için - bir yanıt nesnesi döndürür
#
# status_code : Verileri getirdikten sonra işlemin durumunu (başarı, hata vb.) kontrol edebiliriz.
#
# başlıklar : Başlık türlerini kontrol etmek için
#
# text : metni alınan yanıt nesnesinden çıkarmak için
#
# json : json verilerini çıkarmak için Bu web sitesinden bir txt dosyası okuyalım, https://www.w3.org/TR/PNG/iso_8859-1.txt .

# %%
import requests
url = 'https://www.w3.org/TR/PNG/iso_8859-1.txt'

response = requests.get(url) 
print(response)
print(response.status_code) 
print(response.headers)   
print(response.text)
# Out:
# <Response [200]>
# 200
# {'date': 'Sun, 09 Jan 2022 21:11:27 GMT', 'last-modified': 'Fri, 07 Nov 2003 05:51:11 GMT', 'etag': '"17e9-3cb82080711c0;50c0b26855880-gzip"', 'accept-ranges': 'bytes', 'cache-control': 'max-age=31536000', 'expires': 'Mon, 09 Jan 2023 21:11:27 GMT', 'vary': 'Accept-Encoding', 'content-encoding': 'gzip', 'access-control-allow-origin': '*', 'content-length': '1616', 'content-type': 'text/plain', 'x-backend': 'ssl-mirrors', 'x-request-id': '61db4f7f2cc036d6', 'strict-transport-security': 'max-age=15552000; includeSubdomains; preload', 'content-security-policy': 'upgrade-insecure-requests'}
# The following are the graphical (non-control) characters defined by
# ISO 8859-1 (1987).  Descriptions in words aren't all that helpful,
# but they're the best we can do in text.  A graphics file illustrating
# the character set should be available from the same archive as this
# file.
#
# Hex Description                 Hex Description
#
# 20  SPACE
# ...

# %% [markdown]
# ## Paketler Hakkında Daha Fazla Bilgi
#
# ### Veri tabanı
#
# SQLAlchemy veya SQLObject - Birkaç farklı veritabanı sistemine nesne yönelimli erişim
#
# pip kurulum SQLAlchemy
#
# ### Web Geliştirme
#
# * Django - Üst düzey web çerçevesi.
#
# - pip kurulum django
# Flask - Python için Werkzeug, Jinja 2'ye dayalı mikro çerçeve (BSD lisanslıdır)
#
# - pip install flask
#
# ###  HTML Ayrıştırıcı
#
# *  Beautiful Soup - Ekran kazıma gibi hızlı geri dönüş projeleri için tasarlanmış HTML/XML ayrıştırıcısı, kötü işaretlemeyi kabul edecektir.
#
# - pip kurulumu beautifulsoup4
#
# * PyQuery - Python'da jQuery'yi uygular; görünüşe göre BeautifulSoup'tan daha hızlı.
#
# ###  XML İşleme
#
# ElementTree - Element türü, basitleştirilmiş XML bilgi kümeleri gibi hiyerarşik veri yapılarını bellekte depolamak için tasarlanmış basit ama esnek bir kapsayıcı nesnesidir. --Not: Python 2.5 ve sonraki sürümleri, Standart Kitaplıkta ElementTree'ye sahiptir.
#
# ###  GUI
#
# * PyQt - Platformlar arası Qt çerçevesi için bağlamalar.
#
# * TkInter - Geleneksel Python kullanıcı arabirimi araç takımı.
#
# ### Veri Analizi, Veri Bilimi ve Makine Öğrenimi
#
# * Numpy: Numpy(numeric python), Python'daki en popüler makine öğrenme kitaplıklarından biri olarak bilinir.
#
# * Pandas: Python'da yüksek düzeyde veri yapıları ve analiz için çok çeşitli araçlar sağlayan bir veri analizi, veri bilimi ve makine öğrenimi kitaplığıdır.
#
# * SciPy: SciPy, uygulama geliştiricileri ve mühendisleri için bir makine öğrenimi kitaplığıdır. SciPy kitaplığı optimizasyon, doğrusal cebir, entegrasyon, görüntü işleme ve istatistik için modüller içerir.
#
# * Scikit-Learn: NumPy ve SciPy'dir. Karmaşık verilerle çalışmak için en iyi kitaplıklardan biri olarak kabul edilir.
# TensorFlow: Google tarafından oluşturulmuş bir makine öğrenimi kitaplığıdır.
#
# * Keras: Python'daki en havalı makine öğrenimi kitaplıklarından biri olarak kabul edilir. Sinir ağlarını ifade etmek için daha kolay bir mekanizma sağlar. Keras ayrıca modelleri derlemek, veri kümelerini işlemek, grafikleri görselleştirmek ve çok daha fazlası için en iyi araçlardan bazılarını sağlar.
#
# * Ağ:
#
# request: bir sunucuya istek göndermek için kullanabileceğimiz bir pakettir(GET, POST, DELETE, PUT)
# pip yükleme istekleri
